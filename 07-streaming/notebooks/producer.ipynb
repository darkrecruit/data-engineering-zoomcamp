# %%
import pandas as pd

# %%
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-11.parquet"
columns = ['PULocationID', 'DOLocationID', 'trip_distance', 'total_amount', 'tpep_pickup_datetime']
df = pd.read_parquet(url, columns=columns).head(1000)
df.head()
# Out:
#    PULocationID  DOLocationID  trip_distance  total_amount  \
# 0            43           186           1.68         22.15
# 1           142           237           2.28         24.94
# 2           163           238           2.70         25.62
# 3           138           261          12.87         86.14
# 4           138            37           8.40         48.65
#
#   tpep_pickup_datetime
# 0  2025-11-01 00:13:25
# 1  2025-11-01 00:49:07
# 2  2025-11-01 00:07:19
# 3  2025-11-01 00:00:00
# 4  2025-11-01 00:18:50

# %%
ride = df.iloc[0]

# %%
from dataclasses import dataclass

@dataclass
class Ride:
    PULocationID: int
    DOLocationID: int
    trip_distance: float
    total_amount: float
    tpep_pickup_datetime: int

# %%
import json
def json_serializer(data):
    return json.dumps(data).encode('utf-8')

# %%
import dataclasses

def ride_serializer(ride):
    ride_dict = dataclasses.asdict(ride)
    json_str = json.dumps(ride_dict)
    return json_str.encode('utf-8')

# %%
from kafka import KafkaProducer

server = 'localhost:9092'

producer = KafkaProducer(
    bootstrap_servers=[server],
    value_serializer=ride_serializer
)

# %%
import dataclasses

topic_name = 'rides'

producer.send(topic_name, value=ride)
producer.flush()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       1 import dataclasses
#       3 topic_name = 'rides'
# ----> 5 producer.send(topic_name, value=ride)
#       6 producer.flush()
#
# File /workspaces/data-engineering-zoomcamp/07-streaming/.venv/lib/python3.12/site-packages/kafka/producer/kafka.py:849, in KafkaProducer.send(self, topic, value, key, headers, partition, timestamp_ms)
#     844 self._wait_on_metadata(topic, timer.timeout_ms)
#     846 key_bytes = self._serialize(
#     847     self.config['key_serializer'],
#     848     topic, key)
# --> 849 value_bytes = self._serialize(
#     850     self.config['value_serializer'],
#     851     topic, value)
#     852 assert type(key_bytes) in (bytes, bytearray, memoryview, type(None))
#     853 assert type(value_bytes) in (bytes, bytearray, memoryview, type(None))
#
# File /workspaces/data-engineering-zoomcamp/07-streaming/.venv/lib/python3.12/site-packages/kafka/producer/kafka.py:982, in KafkaProducer._serialize(self, f, topic, data)
#     980 if isinstance(f, Serializer):
#     981     return f.serialize(topic, data)
# --> 982 return f(data)
#
# Cell In[7], line 2, in ride_serializer(ride)
#       1 def ride_serializer(ride):
# ----> 2     ride_dict = dataclasses.asdict(ride)
#       3     json_str = json.dumps(ride_dict)
#       4     return json_str.encode('utf-8')
#
# File ~/.local/share/uv/python/cpython-3.12.12-linux-x86_64-gnu/lib/python3.12/dataclasses.py:1328, in asdict(obj, dict_factory)
#    1309 """Return the fields of a dataclass instance as a new dictionary mapping
#    1310 field names to field values.
#    1311
#    (...)   1325 tuples, lists, and dicts. Other objects are copied with 'copy.deepcopy()'.
#    1326 """
#    1327 if not _is_dataclass_instance(obj):
# -> 1328     raise TypeError("asdict() should be called on dataclass instances")
#    1329 return _asdict_inner(obj, dict_factory)
#
# TypeError: asdict() should be called on dataclass instances
